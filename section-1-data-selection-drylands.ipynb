# %% [markdown]
# Discusssion Section (October 3)

# %%
import pandas as pd

# %% [markdown]
# **What is this data about?**
# This data includes arthropod species occurence in California drylands taken and cleaned up from Global Biodiversity Information Facility.
#
# **Is this data collected in-situ by the authors or is it a synthesis of multiple datasets?**
# This repository includes data from multiple datasets.
#
# **During what time frame were the observations in the dataset collected?**
# Observations in this dataset were taken between 1945 and 2022.
#
# **Does this dataset come with an associated metadata file?**
# Yes, it does come with an associated metadata file.
#
# **Does the dataset contain sensitive data?**
# The data sensitive category for this dataset is considered non-sensitive data.

# %%
# Access metadata from repository
pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A3baf7289-bf90-4db3-ad11-58785c09b26e')
# Out:
#                         attribute  \
# 0                           class
# 1                           order
# 2                          family
# 3                           genus
# 4                         species
# 5                             lat
# 6                            long
# 7                       eventDate
# 8                             day
# 9                           month
# 10                           year
# 11                institutionCode
# 12  coordinateUncertaintyInMeters
# 13                  basisOfRecord
# 14                individualCount
# 15                     datasetKey
# 16                           bio1
# 17                          bio10
# 18                          bio11
# 19                          bio12
# 20                          bio13
# 21                          bio14
# 22                          bio15
# 23                          bio16
# 24                          bio17
# 25                          bio18
# ...

# %%
# Load data
prey = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A23d42528-1048-45d4-85d1-7e13b666e744')

# Check head of csv file
type(prey)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `prey` is a pandas data frame.

# %%
# Show head of prey dataframe
prey.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  ...         bio4        bio5       bio6        bio7        bio8  \
# ...

# %% [markdown]
# We noticed there are 40 columns. Many of the columns are not descriptive (ex: bio1, bio2, etc.) The column names are also in camel case.

# %%
# Display maxcolumns
pd.set_option("display.max.columns", None)
prey.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  year institutionCode  coordinateUncertaintyInMeters  \
# 0    9.0  2020     iNaturalist                          684.0
# ...

# %% [markdown]
# The set_option() code above displays all of the columns of a dataframe instead of the first and last 10 columns.

# %%
# The following code shows the first 5 rows of a dataframe
prey.head()

# The following code shows the last 5 rows of a dataframe.
prey.tail()

# The following code shows the metadata for the dataframe 
# (includes column names, number of entries, datatype of columns, memory usage, non-null values)
prey.info()

# The following code shows the amount of unique observations for each column 
prey.nunique()

# %%
# Change default setting in head
prey.head(10)
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
# 5       Insecta      Diptera        Syrphidae     Allograpta
# 6       Insecta   Orthoptera        Acrididae   Schistocerca
# 7       Insecta  Hymenoptera           Apidae           Apis
# 8       Insecta  Hymenoptera           Apidae           Apis
# 9       Insecta  Lepidoptera      Nymphalidae        Vanessa
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# ...

# %%
# The following code prints the dimensions of the dataframe
print(prey.shape)

# The following code prints a list the columns of the dataframe
print(prey.columns)

# The following code prints the data type of each column
print(prey.dtypes)
# Out:
# (111156, 40)
# Index(['class', 'order', 'family', 'genus', 'species', 'lat', 'long',
#        'eventDate', 'day', 'month', 'year', 'institutionCode',
#        'coordinateUncertaintyInMeters', 'basisOfRecord', 'individualCount',
#        'datasetKey', 'ID', 'bio1', 'bio10', 'bio11', 'bio12', 'bio13', 'bio14',
#        'bio15', 'bio16', 'bio17', 'bio18', 'bio19', 'bio2', 'bio3', 'bio4',
#        'bio5', 'bio6', 'bio7', 'bio8', 'bio9', 'dist', 'dem90_hf', 'lc_class',
#        'ndvi'],
#       dtype='object')
# class                             object
# order                             object
# family                            object
# genus                             object
# species                           object
# lat                              float64
# long                             float64
# eventDate                         object
# day                              float64
# month                            float64
# year                               int64
# ...

# %%
# Rename the institution code and the datasetkey column from camel to snake case
final_df = prey.rename(columns={'institutionCode' : 'institution_code',
                       'datasetKey' : 'dataset_key'})

# Display first 5 columns to check that renaming worked
final_df.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  year institution_code  coordinateUncertaintyInMeters  \
# 0    9.0  2020      iNaturalist                          684.0
# ...
